# %% [markdown]
# <a href="https://colab.research.google.com/github/SPapalonyan/task_10_5/blob/main/task_10_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # task_10_5

# %%
import pandas as pd
from scipy.stats import ttest_ind

def website_analyse(file_path):
    df = pd.read_csv(file_path)

    mean_pages = df["Просмотренные страницы"].mean()
    std_time = df["Время на сайте (сек)"].std()
    mean_time = df["Время на сайте (сек)"].mean()
    cv = std_time / mean_time

    if cv > 0.25:
        variation = "Высокая вариабельность"
    elif cv > 0.1:
        variation = "Умеренная вариабельность"
    else:
        variation = "Слабая вариабельность"

    mobile = df[df["Тип устройства"] == "Мобильное"]["Просмотренные страницы"]
    desktop = df[df["Тип устройства"] == "Десктоп"]["Просмотренные страницы"]

    _, p_value = ttest_ind(mobile, desktop)

    if p_value > 0.05:
        diff = "Есть статистически значимая разница в количестве страниц"
    else:
        diff = "Нет статистически значимой разницы"

    print(f"1) Среднее количество просмотренных страниц: {mean_pages}")
    print(f"2) Стандартное отклонение: {std_time}")
    print(f"3) {variation}: {cv}")
    print(f"4) {diff}: {p_value}")
